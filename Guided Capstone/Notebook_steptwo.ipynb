# %% [markdown]
# # Guided Capstone Step 2 Data Wrangling
#
#
# Data wrangling is the second step in the Data Science Method. This step consists of multiple components including Data Collection, Data Organization, Data Definitions, and Data Cleaning.

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   **Data Wrangling**
#   * Data Collection
#       - Locating the data
#       - Data loading
#       - Data joining
#    * Data Organization
#       -  File structure
#       -  Git & Github
#   * Data Definition
#       - Column names
#       - Data types (numeric, categorical, timestamp, etc.)
#       - Description of the columns
#       - Count or percent per unique values or codes (including NA)
#       - The range of values or codes
#   * Data Cleaning
#       - NA or missing data
#       - Duplicates
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.   Modeling
#
# 6.   Documentation

# %% [markdown]
# ## Data Collection

# %% [markdown]
# First, you'll load the needed packages and modules into Python. Then you'll load the data into a pandas dataframe for ease of use. Run the cell below to get started.

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Now you need to prepare to load the csv file of your data. You may need to change your path to the location where you saved the csv file on your local machine or you need to save both the csv and the notebook to your working project directory.
# Start by printing the current directory. Hint: you can do this by running the command `os.getcwd()`.

# %% [markdown]
# **<font color='teal'> Print the current working directory </font>**

# %%
print(os.getcwd())
# Out:
# /Users/joeboardman/Documents/Springboard/Guided Capstone

# %% [markdown]
# **<font color='teal'> Print the files in your current directory to make sure the 'updated_ski_data.csv' is present. </font>**
#
#
# Hint: if you're not sure on how to do this, this [link](https://www.geeksforgeeks.org/python-os-listdir-method/) can offer guidance.

# %%
print(os.listdir())
# Out:
# ['updated_ski_data (1).csv', '.DS_Store', 'Notebook_stepthree.ipynb', 'GuidedCapstoneStep4 and step5HL.ipynb', 'GuidedCapstoneStep3HL.ipynb', 'Notebook_steptwo.ipynb', 'models', 'Notebook_stepfourandfive.ipynb', 'GuidedCapstone_Step2HL (1).ipynb', 'figures', '.ipynb_checkpoints', 'data', 'Notebook_stepfour.ipynb']

# %% [markdown]
# <font color='teal'> **If you need to change your working directory by defining the path in the next cell make sure to uncomment the code before running the cell. If your path is fine, go on to the Load the data step.**</font>

# %%
#path=""
#os.chdir(path)

# %% [markdown]
# ### Load the data from the csv file
# Now you're ready to read your data into a pandas dataframe. In this exercise, this will complete the data collection step as all the data you need for your project are contained in this one csv file.
# *Double check your path is correct, and that between the `file` name and the `path`, you have the full location of your `updated_ski_data.csv`

# %% [markdown]
# <font color='teal'> **Load the data into a pandas dataframe and print the first five rows of the dataframe.**</font>

# %%
df1 = pd.read_csv('updated_ski_data (1).csv')
df1 = df1.set_index('Name')
print(df1.head())
print(df1.loc['Big Sky Resort', 'fastEight'])
# Out:
#                       Region    state  summit_elev  vertical_drop  base_elev  \
# Name
# Alyeska Resort        Alaska   Alaska         3939           2500        250
# Eaglecrest Ski Area   Alaska   Alaska         2600           1540       1200
# Hilltop Ski Area      Alaska   Alaska         2090            294       1796
# Arizona Snowbowl     Arizona  Arizona        11500           2300       9200
# Sunrise Park Resort  Arizona  Arizona        11100           1800       9200
#
#                      trams  fastEight  fastSixes  fastQuads  quad  ...  \
# Name                                                               ...
# Alyeska Resort           1        0.0          0          2     2  ...
# Eaglecrest Ski Area      0        0.0          0          0     0  ...
# Hilltop Ski Area         0        0.0          0          0     0  ...
# Arizona Snowbowl         0        0.0          1          0     2  ...
# Sunrise Park Resort      0        NaN          0          1     2  ...
#
#                      LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  \
# Name
# Alyeska Resort                 1.0             1610.0           113.0
# Eaglecrest Ski Area            2.0              640.0            60.0
# Hilltop Ski Area               1.0               30.0            30.0
# Arizona Snowbowl               2.0              777.0           104.0
# Sunrise Park Resort            1.2              800.0            80.0
#
#                      daysOpenLastYear  yearsOpen  averageSnowfall  \
# Name
# Alyeska Resort                  150.0       60.0            669.0
# Eaglecrest Ski Area              45.0       44.0            350.0
# Hilltop Ski Area                150.0       36.0             69.0
# Arizona Snowbowl                122.0       81.0            260.0
# Sunrise Park Resort             115.0       49.0            250.0
#
#                      AdultWeekday  AdultWeekend  projectedDaysOpen  \
# Name
# Alyeska Resort               65.0          85.0              150.0
# Eaglecrest Ski Area          47.0          53.0               90.0
# Hilltop Ski Area             30.0          34.0              152.0
# Arizona Snowbowl             89.0          89.0              122.0
# Sunrise Park Resort          74.0          78.0              104.0
#
#                      NightSkiing_ac
# Name
# Alyeska Resort                550.0
# Eaglecrest Ski Area             NaN
# Hilltop Ski Area               30.0
# Arizona Snowbowl                NaN
# Sunrise Park Resort            80.0
#
# [5 rows x 26 columns]
# 1.0

# %% [markdown]
# ## Data Organization

# %% [markdown]
# Data organization for this guided capstone involves creating a basic project folder structure. As you read in the Medium article introducing the data wrangling step, this step is often completed using Github or a module such as cookiecutter. Now that you have your data and your notebook pointing to your working project directory, let's start by printing the current file location. You'll then create a few subfolders to keep your project organized.

# %% [markdown]
# <font color='teal'> **Finish the statement below by assigning the path variable.**</font>

# %%
path = "/Users/joeboardman/Documents/Springboard/Guided Capstone"

# %%
print ("The current working directory is %s" % path)
# Out:
# The current working directory is /Users/joeboardman/Documents/Springboard/Guided Capstone

# %% [markdown]
# ### Create subfolders in your project directory

# %% [markdown]
# Now, create some subfolders inside your project folder.

# %% [markdown]
# <font color='teal'> **Create a subfolder called `data`.**</font>

# %%
data = os.path.join(path, 'data')
os.mkdir(data)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-17-2042ec4c721f> in <module>
#       1 data = os.path.join(path, 'data')
# ----> 2 os.mkdir(data)
#
# FileExistsError: [Errno 17] File exists: '/Users/joeboardman/Documents/Springboard/Guided Capstone/data'

# %% [markdown]
# <font color='teal'> **Create a folder for the data visualizations you will create in future steps called `figures`.**</font>

# %%
figures = os.path.join(path, 'figures')
os.mkdir(figures)

# %% [markdown]
# <font color='teal'> **Create a folder for the models you save, called `models`.**</font>

# %%
models = os.path.join(path, 'models')
os.mkdir(models)

# %% [markdown]
# <font color='teal'> **Print the contents of your project folder to confirm you created the additional folders in your directory.**</font>

# %%
print(os.listdir())

# %% [markdown]
# ## Data Definition
# In this step, you'll review column names, data types, and null values.

# %% [markdown]
# ### Column Names
# <font color='teal'> **Print the columns names of the entire dataframe**</font>

# %%
print(df1.columns)
# Out:
# Index(['Region', 'state', 'summit_elev', 'vertical_drop', 'base_elev', 'trams',
#        'fastEight', 'fastSixes', 'fastQuads', 'quad', 'triple', 'double',
#        'surface', 'total_chairs', 'Runs', 'TerrainParks', 'LongestRun_mi',
#        'SkiableTerrain_ac', 'Snow Making_ac', 'daysOpenLastYear', 'yearsOpen',
#        'averageSnowfall', 'AdultWeekday', 'AdultWeekend', 'projectedDaysOpen',
#        'NightSkiing_ac'],
#       dtype='object')

# %% [markdown]
# ### Data Types
# Review which columns are integer, float, categorical, or dates. Make sure the data type is loaded properly in the dataframe.

# %% [markdown]
# <font color='teal'> **Using the `df.dtypes` function, print the variable names and associated datatypes.**</font>

# %%
print(df1.dtypes)
# Out:
# Region                object
# state                 object
# summit_elev            int64
# vertical_drop          int64
# base_elev              int64
# trams                  int64
# fastEight            float64
# fastSixes              int64
# fastQuads              int64
# quad                   int64
# triple                 int64
# double                 int64
# surface                int64
# total_chairs           int64
# Runs                 float64
# TerrainParks         float64
# LongestRun_mi        float64
# SkiableTerrain_ac    float64
# Snow Making_ac       float64
# daysOpenLastYear     float64
# yearsOpen            float64
# averageSnowfall      float64
# AdultWeekday         float64
# AdultWeekend         float64
# projectedDaysOpen    float64
# NightSkiing_ac       float64
# dtype: object

# %% [markdown]
# <font color='teal'> **The `df.info()` function also prints the count of non-null values per column. Use this function to review the column names, null value counts and data types of your data frame.**</font>

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, Alyeska Resort to White Pine Ski Area
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             330 non-null    object
#  1   state              330 non-null    object
#  2   summit_elev        330 non-null    int64
#  3   vertical_drop      330 non-null    int64
#  4   base_elev          330 non-null    int64
#  5   trams              330 non-null    int64
#  6   fastEight          164 non-null    float64
#  7   fastSixes          330 non-null    int64
#  8   fastQuads          330 non-null    int64
#  9   quad               330 non-null    int64
#  10  triple             330 non-null    int64
#  11  double             330 non-null    int64
#  12  surface            330 non-null    int64
#  13  total_chairs       330 non-null    int64
#  14  Runs               326 non-null    float64
#  15  TerrainParks       279 non-null    float64
#  16  LongestRun_mi      325 non-null    float64
#  17  SkiableTerrain_ac  327 non-null    float64
#  18  Snow Making_ac     284 non-null    float64
#  19  daysOpenLastYear   279 non-null    float64
#  20  yearsOpen          329 non-null    float64
#  21  averageSnowfall    316 non-null    float64
#  22  AdultWeekday       276 non-null    float64
#  23  AdultWeekend       279 non-null    float64
#  24  projectedDaysOpen  283 non-null    float64
#  25  NightSkiing_ac     187 non-null    float64
# dtypes: float64(13), int64(11), object(2)
# memory usage: 79.6+ KB
# None

# %% [markdown]
# Some of these column names are easy to understand but others are not as clear. You have a metadata file with information about each column to help you understand what the column names refer to. Let's review the metadata table below for more information about each column.

# %% [markdown]
# Descriptions of Columns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are some null or missing values you'll need to mitgate in a later step. However, let's look at the counts of unique values or codes per column first.

# %% [markdown]
# ### Count of unique values or codes
# <font color='teal'> **Print the count of unique values for every column, regardless of data type.**</font>

# %%
for column in df1.columns:
    vals = df1[column].nunique()
    print(column, vals)
# Out:
# Region 38
# state 35
# summit_elev 266
# vertical_drop 193
# base_elev 244
# trams 5
# fastEight 2
# fastSixes 7
# fastQuads 14
# quad 7
# triple 9
# double 10
# surface 12
# total_chairs 31
# Runs 110
# TerrainParks 11
# LongestRun_mi 42
# SkiableTerrain_ac 193
# Snow Making_ac 143
# daysOpenLastYear 111
# yearsOpen 72
# averageSnowfall 107
# AdultWeekday 83
# AdultWeekend 81
# projectedDaysOpen 90
# NightSkiing_ac 78

# %% [markdown]
# <font color='teal'> **Print the percent of unique values per column. Use the `df.nunique` and the size of the dataframe to calculate the percentages.**</font>

# %%
for column in df1.columns:
    vals = round((df1[column].nunique() / df1[column].size), 4) * 100
    print(column, str(vals) + '%')
# Out:
# Region 11.52%
# state 10.61%
# summit_elev 80.61%
# vertical_drop 58.48%
# base_elev 73.94%
# trams 1.52%
# fastEight 0.61%
# fastSixes 2.12%
# fastQuads 4.24%
# quad 2.12%
# triple 2.73%
# double 3.0300000000000002%
# surface 3.64%
# total_chairs 9.39%
# Runs 33.33%
# TerrainParks 3.3300000000000005%
# LongestRun_mi 12.73%
# SkiableTerrain_ac 58.48%
# Snow Making_ac 43.33%
# daysOpenLastYear 33.64%
# yearsOpen 21.82%
# averageSnowfall 32.42%
# AdultWeekday 25.15%
# AdultWeekend 24.55%
# projectedDaysOpen 27.27%
# NightSkiing_ac 23.64%

# %% [markdown]
# When working with categorical columns, it's really helpful to know what the unique codes are. <font color='teal'> **For example, if you look at the `Region` or `state` column, youcan print out the different states in the dataframe.**</font>
#
# Hint: you can use the `value_counts()` method for this.

# %%
print(df1.Region.value_counts())
print(df1.state.value_counts())
# Out:
# New York               33
# Michigan               29
# Sierra Nevada          22
# Colorado               22
# Pennsylvania           19
# Wisconsin              16
# New Hampshire          16
# Vermont                15
# Minnesota              14
# Montana                12
# Idaho                  12
# Massachusetts          11
# Washington             10
# New Mexico              9
# Maine                   9
# Wyoming                 8
# Utah                    7
# Oregon                  6
# North Carolina          6
# Salt Lake City          6
# Ohio                    5
# Connecticut             5
# Virginia                4
# Illinois                4
# Mt. Hood                4
# West Virginia           4
# Iowa                    3
# Alaska                  3
# Missouri                2
# Indiana                 2
# New Jersey              2
# South Dakota            2
# Nevada                  2
# Arizona                 2
# Northern California     1
# Rhode Island            1
# Tennessee               1
# Maryland                1
# Name: Region, dtype: int64
# New York          33
# Michigan          29
# Colorado          22
# California        21
# Pennsylvania      19
# New Hampshire     16
# Wisconsin         16
# Vermont           15
# Minnesota         14
# Utah              13
# Montana           12
# Idaho             12
# Massachusetts     11
# Washington        10
# Oregon            10
# New Mexico         9
# Maine              9
# Wyoming            8
# North Carolina     6
# Ohio               5
# Connecticut        5
# Nevada             4
# Illinois           4
# Virginia           4
# West Virginia      4
# Iowa               3
# Alaska             3
# Indiana            2
# Missouri           2
# South Dakota       2
# New Jersey         2
# Arizona            2
# Tennessee          1
# Maryland           1
# Rhode Island       1
# Name: state, dtype: int64

# %% [markdown]
# ### Range of values per column
#
# <font color='teal'>**Print the range of values using the aggregate function.**</font>
#
# Hint: you can do this in a variety of ways, but one way is using the `agg()` dataframe method. You can pass this the `[min, max]` parameter and then call `.T` on the result to transpose it.

# %%
for column in df1.columns:
    print(df1.groupby(column).agg(['min', 'max']).T)
# Out:
# Region                 Alaska  Arizona  Colorado  Connecticut  Idaho  \
# state             min  Alaska  Arizona  Colorado  Connecticut  Idaho
#                   max  Alaska  Arizona  Colorado  Connecticut  Idaho
# summit_elev       min    2090    11100      7136          525   5650
#                   max    3939    11500     13487         1600   9150
# vertical_drop     min     294     1800       440          300    700
#                   max    2500     2300      4425          650   3400
# base_elev         min     250     9200      6696          100   4000
#                   max    1796     9200     10800          950   8000
# trams             min       0        0         0            0      0
#                   max       1        0         3            0      1
# fastEight         min       0        0         0            0      0
#                   max       0        0         0            0      0
# fastSixes         min       0        0         0            0      0
#                   max       0        1         5            0      1
# fastQuads         min       0        0         0            0      0
#                   max       2        1        15            0      9
# quad              min       0        2         0            0      0
#                   max       2        2         4            0      2
# triple            min       0        2         0            0      0
#                   max       1        3         5            5      4
# double            min       0        1         0            0      0
#                   max       4        1         6            2      4
# surface           min       0        0         0            2      0
#                   max       2        2        15            4      4
# total_chairs      min       3        7         1            5      3
#                   max       7        8        40            8     18
# Runs              min      13       55        17           12     11
#                   max      76       65       336           25    120
# TerrainParks      min       1        2         1            2      1
#                   max       2        4        10            4      7
# LongestRun_mi     min       1      1.2       0.6          0.2    0.4
#                   max       2        2         6          1.5    3.2
# SkiableTerrain_ac min      30      777        50           50    280
#                   max    1610      800     26819          107   2900
# Snow Making_ac    min      30       80         5           50      2
#                   max     113      104       680          100    645
# daysOpenLastYear  min      45      115       100           63     60
#                   max     150      122       230          126    149
# yearsOpen         min      36       49        17           50     15
#                   max      60       81       104           72     84
# averageSnowfall   min      69      250       150           45    180
#                   max     669      260       430           92    500
# AdultWeekday      min      30       74        25           30     32
#                   max      65       89       179           62     81
# AdultWeekend      min      34       78        25           42     32
#                   max      85       89       179           65     81
# projectedDaysOpen min      90      104        92           95     70
#                   max     152      122       233          180    193
# NightSkiing_ac    min      30       80        10           35     20
#                   max     550       80       288           66    165
#
# Region                 Illinois  Indiana  Iowa  Maine  Maryland  ...  \
# state             min  Illinois  Indiana  Iowa  Maine  Maryland  ...
#                   max  Illinois  Indiana  Iowa  Maine  Maryland  ...
# summit_elev       min       500      800   975    450      3115  ...
#                   max      1040      900  1500   4237      3115  ...
# vertical_drop     min       100      300   275    240       700  ...
#                   max       475      400   475   2820       700  ...
# base_elev         min       320      400   584    100      2415  ...
#                   max       565      600  1200   1750      2415  ...
# trams             min         0        0     0      0         0  ...
#                   max         0        0     0      1         0  ...
# fastEight         min       NaN        0     0      0       NaN  ...
#                   max       NaN        0     0      0       NaN  ...
# fastSixes         min         0        0     0      0         0  ...
#                   max         0        0     0      0         0  ...
# fastQuads         min         0        0     0      0         0  ...
#                   max         0        1     0      4         0  ...
# quad              min         0        1     0      0         2  ...
#                   max         2        2     1      5         2  ...
# triple            min         0        3     0      0         5  ...
#                   max         4        3     2      3         5  ...
# double            min         0        0     0      0         0  ...
#                   max         2        1     2      5         0  ...
# surface           min         2        2     0      0         5  ...
#                   max         7        6     2      3         5  ...
# total_chairs      min         6        8     2      1        12  ...
#                   max         9       11     6     15        12  ...
# Runs              min         7       15    11     10        34  ...
#                   max        22       23    21    162        34  ...
# TerrainParks      min         1        2     1      1         3  ...
#                   max         3        2     2      5         3  ...
# LongestRun_mi     min       0.1      0.4   0.2    0.3       1.5  ...
#                   max       0.8        1     1    3.5       1.5  ...
# SkiableTerrain_ac min         9       65    35     12       172  ...
#                   max       139      100    55   1240       172  ...
# Snow Making_ac    min         9       65    35     45       118  ...
#                   max       139      100    55    618       118  ...
# daysOpenLastYear  min        56       75   100     67       121  ...
#                   max        87       82   100    165       121  ...
# yearsOpen         min        38       39    22      6        64  ...
#                   max        60       41    58     83        64  ...
# averageSnowfall   min        24       18    30     50       100  ...
#                   max        50       24    45    200       100  ...
# AdultWeekday      min        25       38    29     29        59  ...
#                   max        40       52    40    105        59  ...
# AdultWeekend      min        35       45    39     30        79  ...
#                   max        55       52    46    105        79  ...
# projectedDaysOpen min        70       80   100     58       120  ...
#                   max       112       90   100    169       120  ...
# NightSkiing_ac    min         9       65    35     45       118  ...
#                   max       139      100    55    140       118  ...
#
# Region                Sierra Nevada  South Dakota  Tennessee   Utah  Vermont  \
# state             min    California  South Dakota  Tennessee   Utah  Vermont
#                   max        Nevada  South Dakota  Tennessee   Utah  Vermont
# summit_elev       min          6890          6850       3300   6400     1200
#                   max         11053          7100       3300  10970     4395
# vertical_drop     min           500           940        600    960      650
#                   max          3500          1100        600   2900     3050
# base_elev         min          5500          5900       2700   5440      550
#                   max          8260          6040       2700   9600     2035
# trams             min             0             0          0      0        0
#                   max             3             0          0      3        3
# fastEight         min             0             0        NaN      0        0
#                   max             0             0        NaN      0        0
# fastSixes         min             0             0          0      0        0
#                   max             2             0          0      1        4
# fastQuads         min             0             0          0      0        0
#                   max             9             3          0      2        5
# quad              min             0             0          2      0        0
#                   max             3             0          2      4        5
# triple            min             0             1          0      0        0
#                   max             6             1          0      6        6
# double            min             0             0          1      0        0
#                   max             6             1          1      3        6
# surface           min             0             1          1      0        1
#                   max             8             2          1      3        7
# total_chairs      min             4             4          4      4        3
#                   max            28             5          4     11       22
# Runs              min            14            30         10     23       24
#                   max           154            63         10    167      155
# TerrainParks      min             1             1          1      1        1
#                   max            14             2          1      4       10
# LongestRun_mi     min           0.4           1.2          1    0.4      0.4
#                   max           5.5           1.6          1    3.5        6
# SkiableTerrain_ac min           120           450        NaN    140      100
#                   max          4800           500        NaN   8464     1515
# Snow Making_ac    min            20            50        NaN     84       16
#                   max          3379           225        NaN    625      654
# daysOpenLastYear  min           100            69         83    105       76
#                   max           243           114         83    149      192
# yearsOpen         min            34            51         44      9       53
#                   max            95            65         44     81       86
# averageSnowfall   min           100           150         35    300       90
#                   max           500           200         35    500      349
# AdultWeekday      min            49            45         36     42       45
#                   max           149            58         36    115      119
# AdultWeekend      min            50            45         65     50       73
#                   max           159            58         65    115      119
# projectedDaysOpen min           122            81         94    105       80
#                   max           200           120         94    148      160
# NightSkiing_ac    min            73           NaN        NaN    140       50
#                   max           200           NaN        NaN    300       50
#
# Region                 Virginia  Washington  West Virginia  Wisconsin  Wyoming
# state             min  Virginia  Washington  West Virginia  Wisconsin  Wyoming
#                   max  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# summit_elev       min      1750        3865           3600        995     7428
#                   max      3515        7012           4848       1942    10450
# vertical_drop     min       500        1025            603        200      640
#                   max      1110        3100           1500        700     4139
# base_elev         min      1250        2840           2997        495     6237
#                   max      2512        4570           3430       1300     8798
# trams             min         0           0              0          0        0
#                   max         0           1              0          0        3
# fastEight         min       NaN           0            NaN          0        0
#                   max       NaN           0            NaN          0        0
# fastSixes         min         0           0              0          0        0
#                   max         2           2              0          1        0
# fastQuads         min         0           0              0          0        0
#                   max         0           3              3          3        4
# quad              min         0           0              0          0        0
#                   max         3           8              2          3        4
# triple            min         0           0              2          0        0
#                   max         1           4              6          3        2
# double            min         0           0              0          0        0
#                   max         1          10              2          6        3
# surface           min         0           0              1          0        0
#                   max         5           7              3          6        1
# total_chairs      min         2           3              4          3        2
#                   max         7          27             14         12       15
# Runs              min         8          24             27         12       14
#                   max        27         112             60         75      130
# TerrainParks      min         2           1              1          1        1
#                   max         2           5              5          5        6
# LongestRun_mi     min       0.4         0.6            1.2        0.2      0.4
#                   max         1         2.5              2        1.1      4.5
# SkiableTerrain_ac min        25         355             90         30       75
#                   max       129        2600            257        400     2602
# Snow Making_ac    min        25           5             75         30       18
#                   max       129          66            257        300      250
# daysOpenLastYear  min        68          70             97         42       61
#                   max       107         148            125        136      152
# yearsOpen         min        44          40             36         25        9
#                   max        60          82             48         82       81
# averageSnowfall   min        30         200            100         20       80
#                   max        50         663            180        200      500
# AdultWeekday      min        43          42             52         17       42
#                   max        59          99             72         92       90
# AdultWeekend      min        68          47             68         25       42
#                   max        68          99             92         92       90
# projectedDaysOpen min        95          96             93         42       77
#                   max       121         165            138        139      152
# NightSkiing_ac    min        20          45             27         30      110
#                   max        70         541             86        200      110
#
# [50 rows x 38 columns]
# state                  Alaska  Arizona           California  Colorado  \
# Region            min  Alaska  Arizona  Northern California  Colorado
#                   max  Alaska  Arizona        Sierra Nevada  Colorado
# summit_elev       min    2090    11100                 6890      7136
#                   max    3939    11500                11053     13487
# vertical_drop     min     294     1800                  500       440
#                   max    2500     2300                 3500      4425
# base_elev         min     250     9200                 5500      6696
#                   max    1796     9200                 7953     10800
# trams             min       0        0                    0         0
#                   max       1        0                    3         3
# fastEight         min       0        0                    0         0
#                   max       0        0                    0         0
# fastSixes         min       0        0                    0         0
#                   max       0        1                    2         5
# fastQuads         min       0        0                    0         0
#                   max       2        1                    9        15
# quad              min       0        2                    0         0
#                   max       2        2                    3         4
# triple            min       0        2                    0         0
#                   max       1        3                    6         5
# double            min       0        1                    0         0
#                   max       4        1                    6         6
# surface           min       0        0                    0         0
#                   max       2        2                    8        15
# total_chairs      min       3        7                    4         1
#                   max       7        8                   28        40
# Runs              min      13       55                   10        17
#                   max      76       65                  154       336
# TerrainParks      min       1        2                    1         1
#                   max       2        4                   14        10
# LongestRun_mi     min       1      1.2                  0.4       0.6
#                   max       2        2                  5.5         6
# SkiableTerrain_ac min      30      777                   88        50
#                   max    1610      800                 4800     26819
# Snow Making_ac    min      30       80                   20         5
#                   max     113      104                 3379       680
# daysOpenLastYear  min      45      115                  110       100
#                   max     150      122                  243       230
# yearsOpen         min      36       49                   34        17
#                   max      60       81                   95       104
# averageSnowfall   min      69      250                  100       150
#                   max     669      260                  500       430
# AdultWeekday      min      30       74                   47        25
#                   max      65       89                  149       179
# AdultWeekend      min      34       78                   47        25
#                   max      85       89                  159       179
# projectedDaysOpen min      90      104                  107        92
#                   max     152      122                  200       233
# NightSkiing_ac    min      30       80                   73        10
#                   max     550       80                  200       288
#
# state                  Connecticut  Idaho  Illinois  Indiana  Iowa  Maine  \
# Region            min  Connecticut  Idaho  Illinois  Indiana  Iowa  Maine
#                   max  Connecticut  Idaho  Illinois  Indiana  Iowa  Maine
# summit_elev       min          525   5650       500      800   975    450
#                   max         1600   9150      1040      900  1500   4237
# vertical_drop     min          300    700       100      300   275    240
#                   max          650   3400       475      400   475   2820
# base_elev         min          100   4000       320      400   584    100
#                   max          950   8000       565      600  1200   1750
# trams             min            0      0         0        0     0      0
#                   max            0      1         0        0     0      1
# fastEight         min            0      0       NaN        0     0      0
#                   max            0      0       NaN        0     0      0
# fastSixes         min            0      0         0        0     0      0
#                   max            0      1         0        0     0      0
# fastQuads         min            0      0         0        0     0      0
#                   max            0      9         0        1     0      4
# quad              min            0      0         0        1     0      0
#                   max            0      2         2        2     1      5
# triple            min            0      0         0        3     0      0
#                   max            5      4         4        3     2      3
# double            min            0      0         0        0     0      0
#                   max            2      4         2        1     2      5
# surface           min            2      0         2        2     0      0
#                   max            4      4         7        6     2      3
# total_chairs      min            5      3         6        8     2      1
#                   max            8     18         9       11     6     15
# Runs              min           12     11         7       15    11     10
#                   max           25    120        22       23    21    162
# TerrainParks      min            2      1         1        2     1      1
#                   max            4      7         3        2     2      5
# LongestRun_mi     min          0.2    0.4       0.1      0.4   0.2    0.3
#                   max          1.5    3.2       0.8        1     1    3.5
# SkiableTerrain_ac min           50    280         9       65    35     12
#                   max          107   2900       139      100    55   1240
# Snow Making_ac    min           50      2         9       65    35     45
#                   max          100    645       139      100    55    618
# daysOpenLastYear  min           63     60        56       75   100     67
#                   max          126    149        87       82   100    165
# yearsOpen         min           50     15        38       39    22      6
#                   max           72     84        60       41    58     83
# averageSnowfall   min           45    180        24       18    30     50
#                   max           92    500        50       24    45    200
# AdultWeekday      min           30     32        25       38    29     29
#                   max           62     81        40       52    40    105
# AdultWeekend      min           42     32        35       45    39     30
#                   max           65     81        55       52    46    105
# projectedDaysOpen min           95     70        70       80   100     58
#                   max          180    193       112       90   100    169
# NightSkiing_ac    min           35     20         9       65    35     45
#                   max           66    165       139      100    55    140
#
# state                  ...  Rhode Island  South Dakota  Tennessee  \
# Region            min  ...  Rhode Island  South Dakota  Tennessee
#                   max  ...  Rhode Island  South Dakota  Tennessee
# summit_elev       min  ...           315          6850       3300
#                   max  ...           315          7100       3300
# vertical_drop     min  ...           245           940        600
#                   max  ...           245          1100        600
# base_elev         min  ...            70          5900       2700
#                   max  ...            70          6040       2700
# trams             min  ...             0             0          0
#                   max  ...             0             0          0
# fastEight         min  ...           NaN             0        NaN
#                   max  ...           NaN             0        NaN
# fastSixes         min  ...             0             0          0
#                   max  ...             0             0          0
# fastQuads         min  ...             0             0          0
#                   max  ...             0             3          0
# quad              min  ...             0             0          2
#                   max  ...             0             0          2
# triple            min  ...             0             1          0
#                   max  ...             0             1          0
# double            min  ...             2             0          1
#                   max  ...             2             1          1
# surface           min  ...             2             1          1
#                   max  ...             2             2          1
# total_chairs      min  ...             4             4          4
#                   max  ...             4             5          4
# Runs              min  ...            13            30         10
#                   max  ...            13            63         10
# TerrainParks      min  ...             1             1          1
#                   max  ...             1             2          1
# LongestRun_mi     min  ...           0.2           1.2          1
#                   max  ...           0.2           1.6          1
# SkiableTerrain_ac min  ...            30           450        NaN
#                   max  ...            30           500        NaN
# Snow Making_ac    min  ...            30            50        NaN
#                   max  ...            30           225        NaN
# daysOpenLastYear  min  ...           100            69         83
#                   max  ...           100           114         83
# yearsOpen         min  ...            54            51         44
#                   max  ...            54            65         44
# averageSnowfall   min  ...            40           150         35
#                   max  ...            40           200         35
# AdultWeekday      min  ...           NaN            45         36
#                   max  ...           NaN            58         36
# AdultWeekend      min  ...           NaN            45         65
#                   max  ...           NaN            58         65
# projectedDaysOpen min  ...           100            81         94
#                   max  ...           100           120         94
# NightSkiing_ac    min  ...            30           NaN        NaN
#                   max  ...            30           NaN        NaN
#
# state                            Utah  Vermont  Virginia  Washington  \
# Region            min  Salt Lake City  Vermont  Virginia  Washington
#                   max            Utah  Vermont  Virginia  Washington
# summit_elev       min            6400     1200      1750        3865
#                   max           11068     4395      3515        7012
# vertical_drop     min             960      650       500        1025
#                   max            3240     3050      1110        3100
# base_elev         min            5440      550      1250        2840
#                   max            9600     2035      2512        4570
# trams             min               0        0         0           0
#                   max               4        3         0           1
# fastEight         min               0        0       NaN           0
#                   max               0        0       NaN           0
# fastSixes         min               0        0         0           0
#                   max               6        4         2           2
# fastQuads         min               0        0         0           0
#                   max              13        5         0           3
# quad              min               0        0         0           0
#                   max               4        5         3           8
# triple            min               0        0         0           0
#                   max               7        6         1           4
# double            min               0        0         0           0
#                   max               4        6         1          10
# surface           min               0        1         0           0
#                   max               6        7         5           7
# total_chairs      min               4        3         2           3
#                   max              41       22         7          27
# Runs              min              23       24         8          24
#                   max             341      155        27         112
# TerrainParks      min               1        1         2           1
#                   max               8       10         2           5
# LongestRun_mi     min             0.4      0.4       0.4         0.6
#                   max             3.5        6         1         2.5
# SkiableTerrain_ac min             140      100        25         355
#                   max            8464     1515       129        2600
# Snow Making_ac    min              84       16        25           5
#                   max             750      654       129          66
# daysOpenLastYear  min             105       76        68          70
#                   max             188      192       107         148
# yearsOpen         min               9       53        44          40
#                   max              83       86        60          82
# averageSnowfall   min             300       90        30         200
#                   max             545      349        50         663
# AdultWeekday      min              42       45        43          42
#                   max             169      119        59          99
# AdultWeekend      min              50       73        68          47
#                   max             169      119        68          99
# projectedDaysOpen min             105       80        95          96
#                   max             180      160       121         165
# NightSkiing_ac    min               2       50        20          45
#                   max             300       50        70         541
#
# state                  West Virginia  Wisconsin  Wyoming
# Region            min  West Virginia  Wisconsin  Wyoming
#                   max  West Virginia  Wisconsin  Wyoming
# summit_elev       min           3600        995     7428
#                   max           4848       1942    10450
# vertical_drop     min            603        200      640
#                   max           1500        700     4139
# base_elev         min           2997        495     6237
#                   max           3430       1300     8798
# trams             min              0          0        0
#                   max              0          0        3
# fastEight         min            NaN          0        0
#                   max            NaN          0        0
# fastSixes         min              0          0        0
#                   max              0          1        0
# fastQuads         min              0          0        0
#                   max              3          3        4
# quad              min              0          0        0
#                   max              2          3        4
# triple            min              2          0        0
#                   max              6          3        2
# double            min              0          0        0
#                   max              2          6        3
# surface           min              1          0        0
#                   max              3          6        1
# total_chairs      min              4          3        2
#                   max             14         12       15
# Runs              min             27         12       14
#                   max             60         75      130
# TerrainParks      min              1          1        1
#                   max              5          5        6
# LongestRun_mi     min            1.2        0.2      0.4
#                   max              2        1.1      4.5
# SkiableTerrain_ac min             90         30       75
#                   max            257        400     2602
# Snow Making_ac    min             75         30       18
#                   max            257        300      250
# daysOpenLastYear  min             97         42       61
#                   max            125        136      152
# yearsOpen         min             36         25        9
#                   max             48         82       81
# averageSnowfall   min            100         20       80
#                   max            180        200      500
# AdultWeekday      min             52         17       42
#                   max             72         92       90
# AdultWeekend      min             68         25       42
#                   max             92         92       90
# projectedDaysOpen min             93         42       77
#                   max            138        139      152
# NightSkiing_ac    min             27         30      110
#                   max             86        200      110
#
# [50 rows x 35 columns]
# summit_elev                   315            420            440    450    \
# Region            min  Rhode Island  Massachusetts  Massachusetts  Maine
#                   max  Rhode Island  Massachusetts       Michigan  Maine
# state             min  Rhode Island  Massachusetts  Massachusetts  Maine
#                   max  Rhode Island  Massachusetts       Michigan  Maine
# vertical_drop     min           245            210            200    350
#                   max           245            210            240    350
# base_elev         min            70            210            200    100
#                   max            70            210            240    100
# trams             min             0              0              0      0
#                   max             0              0              0      0
# fastEight         min           NaN              0            NaN    NaN
#                   max           NaN              0            NaN    NaN
# fastSixes         min             0              0              0      0
#                   max             0              0              0      0
# fastQuads         min             0              0              0      0
#                   max             0              0              0      0
# quad              min             0              0              0      0
#                   max             0              0              0      0
# triple            min             0              1              0      0
#                   max             0              1              3      0
# double            min             2              0              1      1
#                   max             2              0              2      1
# surface           min             2              3              2      2
#                   max             2              3              7      2
# total_chairs      min             4              4              4      3
#                   max             4              4             11      3
# Runs              min            13             11             12     20
#                   max            13             11             17     20
# TerrainParks      min             1              1              2    NaN
#                   max             1              1              2    NaN
# LongestRun_mi     min           0.2            0.2            0.1    1.9
#                   max           0.2            0.2            0.5    1.9
# SkiableTerrain_ac min            30             45             45     70
#                   max            30             45             52     70
# Snow Making_ac    min            30             45             45     70
#                   max            30             45             52     70
# daysOpenLastYear  min           100            105            100    102
#                   max           100            105            112    102
# yearsOpen         min            54             50             55     55
#                   max            54             50             70     55
# averageSnowfall   min            40             80             55     90
#                   max            40             80            120     90
# AdultWeekday      min           NaN            NaN             22     32
#                   max           NaN            NaN             48     32
# AdultWeekend      min           NaN            NaN             34     32
#                   max           NaN            NaN             58     32
# projectedDaysOpen min           100            120             90    117
#                   max           100            120            126    117
# NightSkiing_ac    min            30             38             45     45
#                   max            30             38             52     45
#
# summit_elev            495       500          525           528        540    \
# Region            min  Maine  Illinois  Connecticut  Pennsylvania  Minnesota
#                   max  Maine  Michigan  Connecticut  Pennsylvania  Minnesota
# state             min  Maine  Illinois  Connecticut  Pennsylvania  Minnesota
#                   max  Maine  Michigan  Connecticut  Pennsylvania  Minnesota
# vertical_drop     min    240       100          425           450        240
#                   max    240       240          425           450        240
# base_elev         min    255       126          100            78        300
#                   max    255       400          100            78        300
# trams             min      0         0            0             0          0
#                   max      0         0            0             0          0
# fastEight         min    NaN       NaN          NaN             0        NaN
#                   max    NaN       NaN          NaN             0        NaN
# fastSixes         min      0         0            0             0          0
#                   max      0         0            0             0          0
# fastQuads         min      0         0            0             0          0
#                   max      0         0            0             0          0
# quad              min      0         0            0             0          5
#                   max      0         1            0             0          5
# triple            min      0         0            2             1          0
#                   max      0         2            2             1          0
# double            min      2         0            2             3          3
#                   max      2         5            2             3          3
# surface           min      2         6            3             2          2
#                   max      2         7            3             2          2
# total_chairs      min      4         7            7             6         10
#                   max      4        14            7             6         10
# Runs              min     22         7           14             9         19
#                   max     22        25           14             9         19
# TerrainParks      min      2         1            2             1          4
#                   max      2         3            2             1          4
# LongestRun_mi     min    0.3       0.1          0.3           0.2          1
#                   max    0.3       0.2          0.3           0.2          1
# SkiableTerrain_ac min     45         9           51            45         55
#                   max     45       100           51            45         55
# Snow Making_ac    min     45         9           51            45         55
#                   max     45       100           51            45         55
# daysOpenLastYear  min     87        78           63           100        115
#                   max     87        78           63           100        115
# yearsOpen         min     58        53           55            56         43
#                   max     58        58           55            56         43
# averageSnowfall   min     50        20           80            20         50
#                   max     50        25           80            20         50
# AdultWeekday      min     29        39           60           NaN         34
#                   max     29        40           60           NaN         34
# AdultWeekend      min     55        40           60           NaN         46
#                   max     55        47           60           NaN         46
# projectedDaysOpen min    104        70           95           100        120
#                   max    104        70           95           100        120
# NightSkiing_ac    min     45         9           51            45         50
#                   max     45       100           51            45         50
#
# summit_elev                    635    ...     12162     12313     12408  \
# Region            min  Massachusetts  ...  Colorado  Colorado  Colorado
#                   max  Massachusetts  ...  Colorado  Colorado  Colorado
# state             min  Massachusetts  ...  Colorado  Colorado  Colorado
#                   max  Massachusetts  ...  Colorado  Colorado  Colorado
# vertical_drop     min            309  ...      3062      2738      3128
#                   max            309  ...      3062      2738      3128
# base_elev         min            326  ...      9375      9712      9280
#                   max            326  ...      9375      9712      9280
# trams             min              0  ...         0         1         2
#                   max              0  ...         0         1         2
# fastEight         min              0  ...         0         0         0
#                   max              0  ...         0         0         0
# fastSixes         min              0  ...         0         2         2
#                   max              0  ...         0         2         2
# fastQuads         min              0  ...         4         4         4
#                   max              0  ...         4         4         4
# quad              min              0  ...         2         0         1
#                   max              0  ...         2         0         1
# triple            min              0  ...         2         4         1
#                   max              0  ...         2         4         1
# double            min              1  ...         1         4         2
#                   max              1  ...         1         4         2
# surface           min              3  ...         5         9         8
#                   max              3  ...         5         9         8
# total_chairs      min              4  ...        14        24        20
#                   max              4  ...        14        24        20
# Runs              min             16  ...       121       150       128
#                   max             16  ...       121       150       128
# TerrainParks      min              1  ...         4         6         1
#                   max              1  ...         4         6         1
# LongestRun_mi     min            NaN  ...       2.6       1.7       3.5
#                   max            NaN  ...       2.6       1.7       3.5
# SkiableTerrain_ac min             60  ...      1547      2527      3148
#                   max             60  ...      1547      2527      3148
# Snow Making_ac    min             60  ...       297       364       662
#                   max             60  ...       297       364       662
# daysOpenLastYear  min            NaN  ...       145       164       184
#                   max            NaN  ...       145       164       184
# yearsOpen         min             19  ...        58        47        49
#                   max             19  ...        58        47        49
# averageSnowfall   min            NaN  ...       234       300       235
#                   max            NaN  ...       234       300       235
# AdultWeekday      min             40  ...       NaN       158       NaN
#                   max             40  ...       NaN       158       NaN
# AdultWeekend      min             45  ...       NaN       158       NaN
#                   max             45  ...       NaN       158       NaN
# projectedDaysOpen min            NaN  ...       131       164       NaN
#                   max            NaN  ...       131       164       NaN
# NightSkiing_ac    min            NaN  ...       NaN       NaN       288
#                   max            NaN  ...       NaN       NaN       288
#
# summit_elev                 12481     12510     12998     13010     13050  \
# Region            min  New Mexico  Colorado  Colorado  Colorado  Colorado
#                   max  New Mexico  Colorado  Colorado  Colorado  Colorado
# state             min  New Mexico  Colorado  Colorado  Colorado  Colorado
#                   max  New Mexico  Colorado  Colorado  Colorado  Colorado
# vertical_drop     min        3281      4406      3398      2210      2530
#                   max        3281      4406      3398      2210      2530
# base_elev         min        9200      8104      9600     10800     10780
#                   max        9200      8104      9600     10800     10780
# trams             min           1         3         1         0         0
#                   max           1         3         1         0         0
# fastEight         min           0         0         0         0         0
#                   max           0         0         0         0         0
# fastSixes         min           0         1         5         0         0
#                   max           0         1         5         0         0
# fastQuads         min           1        15         6         1         1
#                   max           1        15         6         1         1
# quad              min           3         4         0         3         2
#                   max           3         4         0         3         2
# triple            min           4         3         1         3         1
#                   max           4         3         1         3         1
# double            min           1         5         6         2         2
#                   max           1         5         6         2         2
# surface           min           4         9        15         1         3
#                   max           4         9        15         1         3
# total_chairs      min          14        40        34        10         9
#                   max          14        40        34        10         9
# Runs              min         111       336       187        94       145
#                   max         111       336       187        94       145
# TerrainParks      min           1        10         4         1         3
#                   max           1        10         4         1         3
# LongestRun_mi     min           5       5.3       3.5         2       1.5
#                   max           5       5.3       3.5         2       1.5
# SkiableTerrain_ac min        1294      5517      2908      1800      1428
#                   max        1294      5517      2908      1800      1428
# ...
# surface           min               3               2         7         2
#                   max               3               2         7         5
# total_chairs      min              14               3         7         4
#                   max              14               3         7         5
# Runs              min             170             NaN         7         6
#                   max             170             NaN         7        37
# TerrainParks      min               1               1         1         1
#                   max               1               1         1         1
# LongestRun_mi     min             2.5               1       0.1       0.2
#                   max             2.5               1       0.1         6
# SkiableTerrain_ac min            2500               8         9        10
#                   max            2500               8         9       950
# Snow Making_ac    min             NaN               8         9        10
#                   max             NaN               8         9        25
# daysOpenLastYear  min             188              53        78       100
#                   max             188              53        78       100
# yearsOpen         min              48              55        58        19
#                   max              48              55        58       104
# averageSnowfall   min             500              24        24        60
#                   max             500              24        24       300
# AdultWeekday      min             125              40       NaN        15
#                   max             125              40       NaN        50
# AdultWeekend      min             125              43       NaN        20
#                   max             125              43       NaN        50
# projectedDaysOpen min             180              60        70       100
#                   max             180              60        70       100
#
# NightSkiing_ac            12.0        14.0          15.0      16.0      17.0   \
# Region            min  New York  New Jersey      Illinois  Michigan  Missouri
#                   max  New York  New Jersey  Pennsylvania  Michigan  Missouri
# state             min  New York  New Jersey      Illinois  Michigan  Missouri
#                   max  New York  New Jersey  Pennsylvania  Michigan  Missouri
# summit_elev       min      2400         726           500       900      2566
#                   max      2400         726          3600       900      2566
# vertical_drop     min       650         274            60       320       310
#                   max       650         274          2537       320       310
# base_elev         min      1750         450           320       580      2316
#                   max      1750         450          1700       580      2316
# trams             min         0           0             0         0         0
#                   max         0           0             1         0         0
# fastEight         min         0         NaN             0       NaN         0
#                   max         0         NaN             0       NaN         0
# fastSixes         min         0           0             0         0         0
#                   max         0           0             0         0         0
# fastQuads         min         0           0             0         0         0
#                   max         0           0             2         0         0
# quad              min         1           0             0         0         2
#                   max         1           0             2         0         2
# triple            min         0           0             0         2         2
#                   max         0           0             3         2         2
# double            min         0           2             0         1         0
#                   max         0           2             2         1         0
# surface           min         3           3             3         2         3
#                   max         3           3             6         2         3
# total_chairs      min         4           5             3         5         7
#                   max         4           5            14         5         7
# Runs              min        22          12             3        15        17
#                   max        22          12           110        15        17
# TerrainParks      min         1           1             1         1       NaN
#                   max         1           1             7         1       NaN
# LongestRun_mi     min       1.2         0.3           0.1       0.2       0.1
#                   max       1.2         0.3           4.5       0.2       0.1
# SkiableTerrain_ac min        46          23            15        16        30
#                   max        46          23           439        16        30
# Snow Making_ac    min        18          23            13        16        30
#                   max        18          23           338        16        30
# daysOpenLastYear  min       NaN          80           105        47       NaN
#                   max       NaN          80           142        47       NaN
# yearsOpen         min        71          58            13        34        37
#                   max        71          58            55        34        37
# averageSnowfall   min       120          45            24       150        26
#                   max       120          45           180       150        26
# AdultWeekday      min        40         NaN            17        50        49
#                   max        40         NaN            80        50        49
# AdultWeekend      min        40         NaN            17        50        49
#                   max        40         NaN            88        50        49
# projectedDaysOpen min       NaN         NaN            70        42       NaN
#                   max       NaN         NaN           102        42       NaN
#
# NightSkiing_ac            20.0   ...     288.0     300.0     317.0     400.0  \
# Region            min     Idaho  ...  Colorado  Mt. Hood  Mt. Hood  New York
#                   max  Virginia  ...  Colorado      Utah  Mt. Hood  New York
# state             min     Idaho  ...  Colorado    Oregon    Oregon  New York
#                   max  Virginia  ...  Colorado      Utah    Oregon  New York
# summit_elev       min      1200  ...     12408      8540      5100      2030
#                   max      6300  ...     12408      9422      5100      2030
# vertical_drop     min       450  ...      3128      2522      1500       825
#                   max      2200  ...      3128      3690      1500       825
# base_elev         min       750  ...      9280      6000      3600      1000
#                   max      4100  ...      9280      6900      3600      1000
# trams             min         0  ...         2         0         0         0
#                   max         1  ...         2         0         0         0
# fastEight         min         0  ...         0         0       NaN         0
#                   max         0  ...         0         0       NaN         0
# fastSixes         min         0  ...         2         0         0         0
#                   max         0  ...         2         0         0         0
# fastQuads         min         0  ...         4         1         0         0
#                   max         0  ...         4         5         0         0
# quad              min         0  ...         1         0         0         0
#                   max         1  ...         1         4         0         0
# triple            min         0  ...         1         1         0         1
#                   max         2  ...         1         1         0         1
# double            min         1  ...         2         0         4         1
#                   max         2  ...         2         1         4         1
# surface           min         1  ...         8         1         5         1
#                   max         5  ...         8         3         5         1
# total_chairs      min         3  ...        20         8         9         3
#                   max         7  ...        20         9         9         3
# Runs              min         8  ...       128        41        65        19
#                   max        80  ...       128       167        65        19
# TerrainParks      min         2  ...         1         2         2         1
#                   max         2  ...         1         5         2         1
# LongestRun_mi     min       0.3  ...       3.5         2         3         1
#                   max       2.5  ...       3.5       3.5         3         1
# SkiableTerrain_ac min        25  ...      3148      1415       960       400
#                   max      1600  ...      3148      8464       960       400
# Snow Making_ac    min        25  ...       662       NaN        29       400
#                   max       225  ...       662       NaN        29       400
# daysOpenLastYear  min       100  ...       184       120       125       NaN
#                   max       130  ...       184       305       125       NaN
# yearsOpen         min        29  ...        49        47        82        52
#                   max        57  ...        49        82        82        52
# averageSnowfall   min        30  ...       235       500       300       130
#                   max       300  ...       235       550       300       130
# AdultWeekday      min        26  ...       NaN        88        70        48
#                   max        57  ...       NaN        88        70        48
# AdultWeekend      min        38  ...       NaN        88        70        58
#                   max        68  ...       NaN        88        70        58
# projectedDaysOpen min        95  ...       NaN       146       144        75
#                   max       193  ...       NaN       305       144        75
#
# NightSkiing_ac              450.0       500.0       541.0   550.0    600.0  \
# Region            min  Washington  Washington  Washington  Alaska  Montana
#                   max  Washington  Washington  Washington  Alaska  Montana
# state             min  Washington  Washington  Washington  Alaska  Montana
#                   max  Washington  Washington  Washington  Alaska  Montana
# summit_elev       min        5845        6820        3865    3939     6817
#                   max        5845        6820        3865    3939     6817
# vertical_drop     min        1800        2250        1025    2500     2353
#                   max        1800        2250        1025    2500     2353
# base_elev         min        4061        4570        2840     250     4464
#                   max        4061        4570        2840     250     4464
# trams             min           0           0           0       1        0
#                   max           0           0           0       1        0
# fastEight         min           0           0         NaN       0        0
#                   max           0           0         NaN       0        0
# fastSixes         min           0           0           0       0        0
#                   max           0           0           0       0        0
# fastQuads         min           3           1           3       2        3
#                   max           3           1           3       2        3
# quad              min           0           0           3       2        2
#                   max           0           0           3       2        2
# triple            min           4           0           4       0        6
#                   max           4           0           4       0        6
# double            min           3           3          10       0        0
#                   max           3           3          10       0        0
# surface           min           0           2           7       2        3
#                   max           0           2           7       2        3
# total_chairs      min          10           6          27       7       14
#                   max          10           6          27       7       14
# Runs              min          52         NaN         112      76      105
#                   max          52         NaN         112      76      105
# TerrainParks      min           4           3           5       2        4
#                   max           4           3           5       2        4
# LongestRun_mi     min           1         0.8         0.8       1      3.3
#                   max           1         0.8         0.8       1      3.3
# SkiableTerrain_ac min        1125        2000        1994    1610     3000
#                   max        1125        2000        1994    1610     3000
# Snow Making_ac    min         NaN          66           5     113      600
#                   max         NaN          66           5     113      600
# daysOpenLastYear  min         116         104         120     150      123
#                   max         116         104         120     150      123
# yearsOpen         min          82          53          82      60       72
#                   max          82          53          82      60       72
# averageSnowfall   min         460         200         428     669      333
#                   max         460         200         428     669      333
# AdultWeekday      min         NaN         NaN          85      65       81
#                   max         NaN         NaN          85      65       81
# AdultWeekend      min         NaN         NaN          95      85       81
#                   max         NaN         NaN          95      85       81
# projectedDaysOpen min         145          96         140     150      123
#                   max         145          96         140     150      123
#
# NightSkiing_ac            650.0
# Region            min  New York
#                   max  New York
# state             min  New York
#                   max  New York
# summit_elev       min      1700
#                   max      1700
# vertical_drop     min       550
#                   max       550
# base_elev         min      1150
#                   max      1150
# trams             min         0
#                   max         0
# fastEight         min       NaN
#                   max       NaN
# fastSixes         min         0
#                   max         0
# fastQuads         min         0
#                   max         0
# quad              min         2
#                   max         2
# triple            min         1
#                   max         1
# double            min         4
#                   max         4
# surface           min         3
#                   max         3
# total_chairs      min        10
#                   max        10
# Runs              min        39
#                   max        39
# TerrainParks      min         5
#                   max         5
# LongestRun_mi     min       0.5
#                   max       0.5
# SkiableTerrain_ac min       700
#                   max       700
# Snow Making_ac    min       550
#                   max       550
# daysOpenLastYear  min       103
#                   max       103
# yearsOpen         min        59
#                   max        59
# averageSnowfall   min       120
#                   max       120
# AdultWeekday      min        40
#                   max        40
# AdultWeekend      min        60
#                   max        60
# projectedDaysOpen min       100
#                   max       100
#
# [50 rows x 78 columns]

# %% [markdown]
# <font color='teal'> **Review the numeric dataset's summary statistics.**</font>

# %%
df1.describe()
# Out:
#         summit_elev  vertical_drop     base_elev       trams   fastEight  \
# count    330.000000     330.000000    330.000000  330.000000  164.000000
# mean    4591.818182    1215.427273   3374.000000    0.172727    0.006098
# std     3735.535934     947.864557   3117.121621    0.559946    0.078087
# min      315.000000      60.000000     70.000000    0.000000    0.000000
# 25%     1403.750000     461.250000    869.000000    0.000000    0.000000
# 50%     3127.500000     964.500000   1561.500000    0.000000    0.000000
# 75%     7806.000000    1800.000000   6325.250000    0.000000    0.000000
# max    13487.000000    4425.000000  10800.000000    4.000000    1.000000
#
#         fastSixes   fastQuads        quad     triple      double  ...  \
# count  330.000000  330.000000  330.000000  330.00000  330.000000  ...
# mean     0.184848    1.018182    0.933333    1.50000    1.833333  ...
# std      0.651685    2.198294    1.312245    1.61913    1.815028  ...
# min      0.000000    0.000000    0.000000    0.00000    0.000000  ...
# 25%      0.000000    0.000000    0.000000    0.00000    1.000000  ...
# 50%      0.000000    0.000000    0.000000    1.00000    1.000000  ...
# 75%      0.000000    1.000000    1.000000    2.00000    3.000000  ...
# max      6.000000   15.000000    8.000000    8.00000   14.000000  ...
#
#        LongestRun_mi  SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  \
# count     325.000000         327.000000      284.000000        279.000000
# mean        1.433231         739.801223      174.873239        115.103943
# std         1.156171        1816.167441      261.336125         35.063251
# min         0.000000           8.000000        2.000000          3.000000
# 25%         0.500000          85.000000       50.000000         97.000000
# 50%         1.000000         200.000000      100.000000        114.000000
# 75%         2.000000         690.000000      200.500000        135.000000
# max         6.000000       26819.000000     3379.000000        305.000000
#
#          yearsOpen  averageSnowfall  AdultWeekday  AdultWeekend  \
# count   329.000000       316.000000    276.000000    279.000000
# mean     63.656535       185.316456     57.916957     64.166810
# std     109.429928       136.356842     26.140126     24.554584
# min       6.000000        18.000000     15.000000     17.000000
# 25%      50.000000        69.000000     40.000000     47.000000
# 50%      58.000000       150.000000     50.000000     60.000000
# 75%      69.000000       300.000000     71.000000     77.500000
# max    2019.000000       669.000000    179.000000    179.000000
#
#        projectedDaysOpen  NightSkiing_ac
# count         283.000000      187.000000
# mean          120.053004      100.395722
# std            31.045963      105.169620
# min            30.000000        2.000000
# 25%           100.000000       40.000000
# 50%           120.000000       72.000000
# 75%           139.500000      114.000000
# max           305.000000      650.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handle the missing and NA values
# Run the code below to print out the percent of each feature that is missing. You can see from the result of the code that there are 13 columns out of 27 missing data. Most of these are missing less than 10% of the data. You may need to adapt the code if your dataframe is named something other than df.
#
#
# *   Consider the columns individually
# *   Identify the appropriate fill method for each column

# %%
nas=pd.DataFrame(df1.isnull().sum().sort_values(ascending=False)/len(df1),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#                     percent
# fastEight          0.503030
# NightSkiing_ac     0.433333
# AdultWeekday       0.163636
# AdultWeekend       0.154545
# daysOpenLastYear   0.154545
# TerrainParks       0.154545
# projectedDaysOpen  0.142424
# Snow Making_ac     0.139394
# averageSnowfall    0.042424
# LongestRun_mi      0.015152
# Runs               0.012121
# SkiableTerrain_ac  0.009091
# yearsOpen          0.003030

# %% [markdown]
# Let's review each of these columns in the data.
#
#
# *   fastEight is the number of fast eight-person ski lifts at each of the resorts. In addition, you have the counts of all the other types of chairs at each resort and the total number of chairs as well. You can simply subtract the number of fastEight lifts from the total to determine if any of the missing values can be backfilled or if they should be equal to zero. Follow the next step below and see for yourself how to review and backfill these missing values. These columns contain all the resort lift counts by type.
#
#
# * trams
# * fastEight
# * fastSixes
# * fastQuads
# * quad
# * triple
# * double
# * surface
# * total_chairs <- the sum of these columns for each row.

# %% [markdown]
# <font color='teal'> **In order to determine an appropriate fill value for the fastEigth column, you need to calculate the difference between the sum of all the chairlift columns and the `total_chairs` column.**</font>

# %%
lifts = ['trams', 'fastEight', 'fastSixes', 'fastQuads', 'quad', 'triple', 'double', 'surface', 'total_chairs']

df2 = df1.groupby(['Name'])[lifts].sum()
df3 = df2.transpose()
#this allows us to see all of the chair columns for big sky that adds up to 35
print(df2.head(30))
#this shows the number of total_chairs at big sky equals 36
print(df3.iloc[7, 27])

#Using this formula, I found a variance of 1 in big sky - index 27 in df2
for name in range(len(df2)):
    vals = df3.iloc[8, name] - df3.iloc[0, name] - df3.iloc[1, name] - df3.iloc[2, name] - df3.iloc[3, name] - df3.iloc[4, name] - df3.iloc[5, name] - df3.iloc[6, name] - df3.iloc[7, name]
    #print(name, vals)
    
print('The number of missing fastEight chairs is ' + str(vals.sum()))
#I thought big sky's fastEight column was NaN and should have been 1, but it was already 1
# Out:
#                                        trams  fastEight  fastSixes  fastQuads  \
# Name
# 49 Degrees North                           0        0.0          0          0
# Afton Alps                                 0        0.0          0          0
# Alpental                                   0        0.0          0          1
# Alpine Valley                              0        0.0          0          0
# Alpine Valley Resort                       0        0.0          0          3
# Alpine Valley Ski Area                     0        0.0          0          0
# Alta Ski Area                              0        0.0          0          3
# Alyeska Resort                             1        0.0          0          2
# Andes Tower Hills Ski Area                 0        0.0          0          0
# Angel Fire Resort                          0        0.0          0          2
# Anthony Lakes Mountain Resort              0        0.0          0          0
# Appalachian Ski Mountain                   0        0.0          0          0
# Apple Mountain                             0        0.0          0          0
# Arapahoe Basin Ski Area                    0        0.0          0          1
# Arizona Snowbowl                           0        0.0          1          0
# Aspen / Snowmass                           3        0.0          1         15
# Attitash                                   0        0.0          0          2
# Bear Creek Mountain Resort                 0        0.0          0          0
# Bear Mountain                              0        0.0          0          2
# Bear Valley                                0        0.0          1          1
# Beaver Creek                               2        0.0          0         11
# Beaver Mountain                            0        0.0          0          0
# Beech Mountain Resort                      0        0.0          0          0
# Belleayre                                  1        0.0          0          1
# Berkshire East                             0        0.0          0          0
# Big Boulder                                0        0.0          0          0
# Big Powderhorn Mountain                    0        0.0          0          0
# Big Sky Resort                             1        1.0          2          5
# Big Snow Resort - Blackjack                0        0.0          0          0
# Big Snow Resort - Indianhead Mountain      0        0.0          0          0
#
#                                        quad  triple  double  surface  \
# Name
# 49 Degrees North                          1       0       5        1
# Afton Alps                                1       3      14        4
# Alpental                                  0       0       3        1
# Alpine Valley                             1       2       1        1
# Alpine Valley Resort                      0       3       1        5
# Alpine Valley Ski Area                    1       2       5        6
# Alta Ski Area                             0       1       2        0
# Alyeska Resort                            2       0       0        2
# Andes Tower Hills Ski Area                1       2       0        3
# Angel Fire Resort                         0       0       3        2
# Anthony Lakes Mountain Resort             0       1       0        2
# Appalachian Ski Mountain                  2       0       1        2
# Apple Mountain                            1       0       0        5
# Arapahoe Basin Ski Area                   2       1       2        3
# Arizona Snowbowl                          2       2       1        2
# Aspen / Snowmass                          4       3       5        9
# Attitash                                  1       3       2        1
# Bear Creek Mountain Resort                3       1       0        2
# Bear Mountain                             1       2       3        4
# Bear Valley                               0       2       4        2
# Beaver Creek                              0       1       1        9
# Beaver Mountain                           0       1       3        1
# Beech Mountain Resort                     3       0       3        2
# Belleayre                                 1       1       2        2
# Berkshire East                            2       1       1        2
# Big Boulder                               0       2       5        1
# Big Powderhorn Mountain                   0       0       9        1
# Big Sky Resort                            3       7       5       12
# Big Snow Resort - Blackjack               0       0       4        2
# Big Snow Resort - Indianhead Mountain     1       1       5        2
#
#                                        total_chairs
# Name
# 49 Degrees North                                  7
# Afton Alps                                       22
# Alpental                                          5
# Alpine Valley                                     5
# Alpine Valley Resort                             12
# Alpine Valley Ski Area                           14
# Alta Ski Area                                     6
# Alyeska Resort                                    7
# Andes Tower Hills Ski Area                        6
# Angel Fire Resort                                 7
# Anthony Lakes Mountain Resort                     3
# Appalachian Ski Mountain                          5
# Apple Mountain                                    6
# Arapahoe Basin Ski Area                           9
# Arizona Snowbowl                                  8
# Aspen / Snowmass                                 40
# Attitash                                          9
# Bear Creek Mountain Resort                        6
# Bear Mountain                                    12
# Bear Valley                                      10
# Beaver Creek                                     24
# Beaver Mountain                                   5
# Beech Mountain Resort                             8
# Belleayre                                         8
# Berkshire East                                    6
# Big Boulder                                       8
# Big Powderhorn Mountain                          10
# Big Sky Resort                                   36
# Big Snow Resort - Blackjack                       6
# Big Snow Resort - Indianhead Mountain             9
# 12.0
# The number of missing fastEight chairs is 0.0

# %% [markdown]
# As you can see from running the above cell, there are no fastEight lift values missing because the difference between the sum of all the lift columns and the 'total_chairs' column is zero for every row in the dataframe. This confirms that you can therefore replace the missing values for the fastEight rows with zeros.

# %% [markdown]
# <font color='teal'> **In the cell below, replace Nan's in 'fastEight' with zero.**</font>
#
# Hint: you could use the `fillna()` method here.

# %%
df1['fastEight'].fillna(value=0, inplace=True)
df1['NightSkiing_ac'].fillna(value=0, inplace=True)

# %% [markdown]
# Consider the next column with missing values, 'NightSkiing_ac'. This column represents the number of acres of night skiing availble at this resort. Not all resorts have night skiing because it requires stadium lights and is not that popular with skiers and snowboarders. Given that information, it is also safe to assume that if there are missing values in this column, it is due to there not being any night skiing acres available at that resort so you can fill missing values with zeros safely.

# %% [markdown]
# Next, let's consider the ticket price columns 'AdultWeekday' & 'AdultWeekend'. You know that there has to be a price for these that happens to be missing so, in this case, you cannot fill the missing values with zeros. Instead, you have a few options about what value you can use to fill the missing rows. You can simply take the mean of the column in consideration or you could backfill or forwardfill from the resort in the row before or after your missing value. Backfill and forward fill would be more reasonable in a situation where the data are in a particular order where the rows near each other are similar to each other in the price column. You could also build an imputation model to use a model to predict the value based on the data values in adjacent columns as well as adjacent rows.

# %% [markdown]
# <font color='teal'> **Run the cell below to replace Nan's in 'AdultWeekday' with the mean value.**</font>

# %%
df1['AdultWeekday'].fillna((df1['AdultWeekday'].mean()), inplace=True)

# %% [markdown]
# <font color='teal'> **Use what you know about the remaining columns missing data and decide whether to fill with a zero or to fill with a mean.**</font>

# %%
#Fillna with zeros
df1['TerrainParks'].fillna(value=0, inplace=True)
df1['Snow Making_ac'].fillna(value=0, inplace=True)

# %%
#Fillna with the mean
df1['AdultWeekend'].fillna((df1['AdultWeekend'].mean()), inplace=True)
df1['daysOpenLastYear'].fillna((df1['daysOpenLastYear'].mean()), inplace=True)
df1['projectedDaysOpen'].fillna((df1['projectedDaysOpen'].mean()), inplace=True)
df1['averageSnowfall'].fillna((df1['averageSnowfall'].mean()), inplace=True)
df1['LongestRun_mi'].fillna((df1['LongestRun_mi'].mean()), inplace=True)
df1['Runs'].fillna((df1['Runs'].mean()), inplace=True)
df1['SkiableTerrain_ac'].fillna((df1['SkiableTerrain_ac'].mean()), inplace=True)
df1['yearsOpen'].fillna((df1['yearsOpen'].mean()), inplace=True)

# %% [markdown]
# ### Look for duplicate rows
# Run the code below to print out the duplicated rows.You can see there are no duplicate rows, so in this particular case there is nothing else to do related to duplicate rows. You will review duplicate or synonymous columns in Step 3 of the Guided Capstone.

# %%
duplicateRowsDF = df1[df1.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [Region, state, summit_elev, vertical_drop, base_elev, trams, fastEight, fastSixes, fastQuads, quad, triple, double, surface, total_chairs, Runs, TerrainParks, LongestRun_mi, SkiableTerrain_ac, Snow Making_ac, daysOpenLastYear, yearsOpen, averageSnowfall, AdultWeekday, AdultWeekend, projectedDaysOpen, NightSkiing_ac]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## Export data to a new csv file
# In order to bring the changes you made here into the next notebook, you need to write out the updated data frame to a new csv file.

# %% [markdown]
# <font color='teal'> **Export the processed dataframe as a csv file to the data folder you created earlier. Name this new csv file `step2_output.csv`.**</font>
#
# Hint: you can use the `to_csv()` dataframe method here.

# %%
data2 = os.path.join(data, 'step2_output.csv')
df1.to_csv(data2)

# %% [markdown]
# The data transformations created in this step of the DSM are all generally steps to be applied to any data science project. However, the decisions we made about how to handle the missing and NA data are specific to the problem at hand. In the next step of the DSM and the next Guided Capstone Notebook, you'll see how all these steps prepare the data for exploratory data analysis.
